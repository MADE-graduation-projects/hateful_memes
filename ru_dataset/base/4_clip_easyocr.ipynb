# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as img

import json

from torchvision import transforms as T
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms.functional as F

import torch
import os

import numpy as np


from torch.utils.data import DataLoader
from tqdm import tqdm

import cv2

import clip
from PIL import Image

import torch.nn as nn

from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

from prettytable import PrettyTable

import optuna

# %%
column_name = 'recognized_text_easyocr'

# %%
def get_features(model, dataset):
    all_features = []
    all_labels = []
    
    with torch.no_grad():
        for images, texts, labels, path in tqdm(DataLoader(dataset, batch_size=100)):
            
            image_input = torch.tensor(np.stack(images)).cuda()
            text_tokens = clip.tokenize([desc[:50] for desc in texts]).cuda()
            
            image_features = model.encode_image(image_input).type(torch.float).cpu()
            text_features = model.encode_text(text_tokens).type(torch.float).cpu()

            features = torch.cat([image_features, text_features], dim=1)
            
            all_features.extend(features)
            all_labels.extend(labels)

    return all_features, all_labels


def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']


def train_model(model, train_loader, val_loader, loss, optimizer, num_epochs, scheduler):    
    best_model_name = None
    loss_history = []
    train_history = []
    val_history = []
    top_val_accuracy = 0.52 
    for epoch in range(num_epochs):
        model.train()
        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        for i_step, (x, y) in enumerate(train_loader):
            x=x.type(torch.float).cpu()
            y = y.type(torch.float).cpu()
            model = model.cpu()
            prediction = model(x)    
            loss_value = loss(prediction, y.type(torch.long))
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()
            
            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y)
            total_samples += y.shape[0]
            
            loss_accum += loss_value

        ave_loss = loss_accum / (i_step + 1)
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)
        
        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)
        if scheduler != None:
            scheduler.step()

        print("Epoch: %i lr: %f; Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (epoch, get_lr(optimizer), ave_loss, train_accuracy, val_accuracy))

  
        if val_accuracy > top_val_accuracy:
            top_val_accuracy = val_accuracy
            model_name = f'classifier_{epoch}_{round(val_accuracy, 3)}.ckpt'
            best_model_name = model_name
            torch.save(model, open(model_name, 'wb'))
            print("saved", model_name)

    return loss_history, train_history, val_history, best_model_name
        
    
def compute_accuracy(model, loader):
    """
    Computes accuracy on the dataset wrapped in a loader    
    Returns: accuracy as a float value between 0 and 1
    """
    model.eval()
    correct_samples = 0
    total_samples = 0 
    for i_step, (x, y) in enumerate(loader):
        prediction = model(x)
        _, indices = torch.max(prediction, 1)
        correct_samples += torch.sum(indices == y)
        total_samples += y.shape[0]            

    val_accuracy = float(correct_samples) / total_samples
         
    return val_accuracy

# %%
prettyTable = PrettyTable(['Model name', 'Accuracy', 'ROC AUC'])

# %%
from classes.transforms.CropCenter import CropCenter
from classes.transforms.ScaleMaxSideToSize import ScaleMaxSideToSize
from classes.dataset.FeaturesDataset import FeaturesDataset

# %%
import torch
import json
import os
from PIL import Image
import cv2
from cv2 import cv2


class HatefulMemesDataset(torch.utils.data.Dataset):
    def __init__(self, data_path, transforms, column_name):
        self.data = [json.loads(l) for l in open(data_path)]
        
        self.data = [x for x in self.data if x['label'] != 3]
        for x in self.data:
            if x['label'] != 0:
                x['label'] = 1
                
        self.data_dir = os.path.dirname(data_path)
        self.transforms = transforms
        self.column_name = column_name
        
    def __getitem__(self, index: int):
        #image = Image.open(os.path.join(self.data_dir, self.data[index]["img"]))   
        
        path = os.path.join(self.data_dir, self.data[index]["img"])
        image = cv2.imread(path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        text = self.data[index][self.column_name]
        label = self.data[index]["label"]

        if self.transforms is not None:
            image = self.transforms(image)
            
        return image, text, label, path
    
    def __len__(self):
        return len(self.data)

# %%
CROP_SIZE=224

# %%
data_dir = r'C:\Users\notebook\Downloads\_my_dataset\20221214_hateful_memes\hateful_memes\\'

# %%
train_path = data_dir + 'train_trans.jsonl'
dev_path = data_dir + 'test_trans.jsonl'

train_data = pd.read_json(train_path, lines=True)
test_data = pd.read_json(dev_path, lines=True)

# %%
train_data
# Out:
#      label               img  \
# 0        3  img/10910387.jpg
# 1        3  img/10747369.jpg
# 2        0  img/13996726.jpg
# 3        1   img/9987066.jpg
# 4        0  img/16702250.jpg
# ..     ...               ...
# 626      3  img/14293988.jpg
# 627      3  img/13082683.jpg
# 628      0  img/15659398.jpg
# 629      0  img/12081951.jpg
# 630      0  img/13082779.jpg
#
#                                recognized_text_easyocr  \
# 0    Бг]~яЁЦШ ВваЗКЕ;а ~БецЕаноляЕБа #д ГеияТЪ_Цы ш...
# 1                    [ы КУбШШЬ? ТШЛЬКШ КЛЁДАМУЕЮ: # -Ш
# 2    ОКАЗАЛОСЬ МОЯ СЕСТРА ПО НОЧАМ ЗАНИМАЕТСЯ ПРОСТ...
# 3
# 4                       ВЕМШДШЧЮИ ЩЛ ЛАЙК ПШВТПВШЮ Е#я
# ..                                                 ...
# 626                           МШТЯП Ктьйе ПОДШЕ ПДИШЛМ
# 627  СКОЛЬКО ВЕСИТ ИДЕАЛЬНЫЙ ЕВРЕЙ? 0,2 КИЛОГРАММА ...
# 628
# 629                   ~"Яе  эяю @елъ_у_~__ [ @едеек Ы₽
# 630
#
#                                        translated_text
# 0    Бг] ~ яЁЦШ ВваЗКЕ; а ~ БецЕноляЕБа # д ГеияТЬ ...
# 1                  [s КУБШШШЬ? ТШЛЬKS КЛЁДАМУВЕЯ: # -Ш
# 2    MY SISTER IS BELIEVED BY PROSTITUTION AT NIGHT...
# 3     In fact, there is no such thing as a free lunch.
# 4                  ВЕМШДШЧУИ ШЛЫК ЛАЙК ПШВВВШВШЕ Е # я
# ..                                                 ...
# 626                                      KATIE HOPKINS
# 627  How much does an IDEAL EURY weigh? 0.2 CILOGRA...
# 628   In fact, there is no such thing as a free lunch.
# 629       ~ "Ye ejaculate @ el _ y _ _ _ _ [@ edshew]"
# 630   In fact, there is no such thing as a free lunch.
#
# [631 rows x 4 columns]

# %%
test_data
# Out:
#      label               img  \
# 0        0  img/13037928.jpg
# 1        6   img/9664522.jpg
# 2        1  img/15448302.jpg
# 3        0  img/16702294.jpg
# 4        0  img/15244154.jpg
# ..     ...               ...
# 206      1  img/12954537.jpg
# 207      6  img/16180208.jpg
# 208      0  img/15244043.jpg
# 209      0  img/14993032.jpg
# 210      0  img/11675220.jpg
#
#                                recognized_text_easyocr  \
# 0    сЕе- ИУшЕЕ ИЕКАРСТЕО ПАП НУ Я УЖЕ, ЕЫзДОРОВИЙ ...
# 1               ПЛКЕНше #+ ааыТь МЯГИ пипа: щп8 ФыФщСЙ
# 2    Она: рсе; мне болыше не нужны мужики] € эгого ...
# 3    Измени свою жилнь (РИстИанствовё хорошо хоть в...
# 4    Невидимый кЕ@е[ и Хэнк Всадннки ЯП Апокалипснс...
# ..                                                 ...
# 206  "25 :"5й@4?й; #"; 4; ЕЕМ4И '415д - "44 < ЁЖ5{4...
# 207
# 208  Да чТа { @Жет бть кужсе, чем несколько детей М...
# 209  КГДАЛРИ ЧИСКЕ МАНДАРШНМ #ЕЧЫВСАВЧЕШЬ ЗИПАХА ЮВ...
# 210  Оригинальный чехол для телефона ож'ш& Да нафиг...
#
#                                        translated_text
# 0    CY-JESE JEKARSTEO PAP I AM NO YEARS, NO YEARS:...
# 1             PLKENSHE # + ааыТь МяГИ пипа: щп8 ФыФщСY
# 2    She: rse; I don't need men anymore] I'm a prou...
# 3    Change your dwelling (RISTYANSTEVO is good eve...
# 4    The Invisible KE @ e [and Hank Horseshoe of JP...
# ..                                                 ...
# 206  "25:" 5th @ 4? y; # "; 4; ЕЕМ4И '415d -" 44 < ...
# 207   In fact, there is no such thing as a free lunch.
# 208  Yes read {@ Jet bt kuzse than a few children b...
# 209  KGDALRI CHISKE MANDARSHIP # CHISKE ZIPAHA YUSH...
# 210  The original phone case oj'sh & Yes naphig is ...
#
# [211 rows x 4 columns]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
clip.available_models()
# Out:
# ['RN50',
#  'RN101',
#  'RN50x4',
#  'RN50x16',
#  'RN50x64',
#  'ViT-B/32',
#  'ViT-B/16',
#  'ViT-L/14',
#  'ViT-L/14@336px']

# %% [markdown]
# ### CLIP zero-shot learning

# %%
#https://github.com/openai/CLIP
model, preprocess = clip.load("ViT-L/14", device=device)

image = preprocess(Image.open("CLIP.png")).unsqueeze(0).to(device)
text = clip.tokenize(["a diagram", "a dog", "a cat"]).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print("Label probs:", probs)  # prints: [[0.9927937  0.00421068 0.00299572]]
# Out:
# Label probs: [[0.946    0.04822  0.005985]]

# %%
plt.imshow(Image.open("CLIP.png"))

# %%
preprocess
# Out:
# Compose(
#     Resize(size=224, interpolation=bicubic, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     <function _convert_image_to_rgb at 0x000001E909169700>
#     ToTensor()
#     Normalize(mean=(0.48145466, 0.4578275, 0.40821073), std=(0.26862954, 0.26130258, 0.27577711))
# )

# %% [markdown]
# #### Предобработка изображений

# %%
MEAN = torch.tensor([0.485, 0.456, 0.406])
STD = torch.tensor([0.229, 0.224, 0.225])

# %%
transforms = T.Compose([
    ScaleMaxSideToSize(CROP_SIZE),
    CropCenter(CROP_SIZE),
    T.ToTensor(),
    T.Normalize(mean=MEAN, std=STD),
])

# %%
train_dataset = HatefulMemesDataset(train_path, transforms, column_name)
val_dataset = HatefulMemesDataset(dev_path, transforms, column_name)

# %%
for images, texts, labels, path in tqdm(DataLoader(train_dataset, batch_size=8)):
    #print(images[0].shape, texts[0], labels[0] , labels.shape)
    break
    
grid = torchvision.utils.make_grid([(x * STD[:, None, None] + MEAN[:, None, None]) for x in images], nrow = 4)#
plt.figure(figsize=(30,20)); 
plt.axis(False)
plt.imshow(F.to_pil_image(grid));

print(texts)
# Out:
#   0%|                                                                                           | 0/60 [00:00<?, ?it/s]
# ('ОКАЗАЛОСЬ МОЯ СЕСТРА ПО НОЧАМ ЗАНИМАЕТСЯ ПРОСТИТУЦИЕЙ; ПОЭТОМУ ПРЕДЫДУЩИЕ ДВЕ НЕДЕЛИ Я КАЖДЫЙ ДЕНЬ ЗАБИРАЛ ЕЕ С УЛИЦЫ ОБЫЧНО НА ЧАС ИЛИ ОКОЛО ТОГО', '', 'ВЕМШДШЧЮИ ЩЛ ЛАЙК ПШВТПВШЮ Е#я', 'КОГДА ВИДИШЬ СВОЮ БЫВШУЮ НОВЫМ ПАРНЕМ АТЫ ПОМНИШЬ ВСЕ МОМЕНТЫ КАК ОНА ЛИЗАЛА ТВОЮ ЖОПУ Я ЗНАЮ ТО, ЧЕГО НЕ ЗНАЕШЬ ТЫ', 'МОН @РЭУШШНиДеЯМ4459В: ШеадиБШНОпдеШШы ОШЛ#ВИзОН; ЧшЛЫВЫОРННДПеЙМНЛМОВИОПЦЛИВаШ ВУнШЖИ НеШЧПНШЛЮНйефЬ', 'ВЫ тожжЕ Иж ВИДИТЕ?', 'в сеть слиты кадры секретный саж1олёт армении', '')

# %% [markdown]
# #### Извлекаем признаки из текста и картинок

# %%
features_train, labels_train = get_features(model, train_dataset)
features_val, labels_val = get_features(model, val_dataset)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:09<00:00,  1.82s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:03<00:00,  1.23s/it]

# %%
features_train_dataset = FeaturesDataset(features_train, labels_train)
features_val_dataset = FeaturesDataset(features_val, labels_val)

# %% [markdown]
# #### Обучение нейросети

# %%
input_shape = features_train_dataset[0][0].shape[0]
num_classes = 2

# %%
input_shape
# Out:
# 1536

# %%
torch.manual_seed(1024)

shape = 256
nn_model = nn.Sequential(
            nn.Linear(input_shape, shape),
            nn.Dropout(0.66),
            nn.BatchNorm1d(shape),
            nn.ReLU(inplace=True),    
    
            nn.Linear(shape, shape),
            nn.Dropout(0.66),
            nn.BatchNorm1d(shape),
            nn.ReLU(inplace=True),    
    
            nn.Linear(shape, num_classes),
            )

print(nn_model)
loss = nn.CrossEntropyLoss().cpu()
optimizer = torch.optim.Adam(nn_model.parameters(), lr=1e-2)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.8)

loss_history, train_history, val_history, best_model_name = train_model(
    nn_model, 
    DataLoader(features_train_dataset, batch_size=500),
    DataLoader(features_val_dataset, batch_size=500),
    loss, optimizer, 200, scheduler)
print('end!')
# Out:
# Sequential(
#   (0): Linear(in_features=1536, out_features=256, bias=True)
#   (1): Dropout(p=0.66, inplace=False)
#   (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): ReLU(inplace=True)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): Dropout(p=0.66, inplace=False)
#   (6): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): ReLU(inplace=True)
#   (8): Linear(in_features=256, out_features=2, bias=True)
# )
# Epoch: 0 lr: 0.010000; Average loss: 0.736318, Train accuracy: 0.511530, Val accuracy: 0.618357
# saved classifier_0_0.618.ckpt
# Epoch: 1 lr: 0.010000; Average loss: 0.839262, Train accuracy: 0.557652, Val accuracy: 0.381643
# Epoch: 2 lr: 0.010000; Average loss: 0.723585, Train accuracy: 0.524109, Val accuracy: 0.381643
# Epoch: 3 lr: 0.010000; Average loss: 0.741435, Train accuracy: 0.480084, Val accuracy: 0.381643
# Epoch: 4 lr: 0.010000; Average loss: 0.672607, Train accuracy: 0.578616, Val accuracy: 0.512077
# Epoch: 5 lr: 0.010000; Average loss: 0.694275, Train accuracy: 0.595388, Val accuracy: 0.512077
# Epoch: 6 lr: 0.010000; Average loss: 0.693603, Train accuracy: 0.601677, Val accuracy: 0.425121
# Epoch: 7 lr: 0.010000; Average loss: 0.662365, Train accuracy: 0.593291, Val accuracy: 0.400966
# Epoch: 8 lr: 0.010000; Average loss: 0.663933, Train accuracy: 0.578616, Val accuracy: 0.439614
# Epoch: 9 lr: 0.008000; Average loss: 0.647060, Train accuracy: 0.607966, Val accuracy: 0.560386
# Epoch: 10 lr: 0.008000; Average loss: 0.622892, Train accuracy: 0.660377, Val accuracy: 0.608696
# Epoch: 11 lr: 0.008000; Average loss: 0.615226, Train accuracy: 0.651992, Val accuracy: 0.628019
# saved classifier_11_0.628.ckpt
# Epoch: 12 lr: 0.008000; Average loss: 0.624795, Train accuracy: 0.620545, Val accuracy: 0.599034
# Epoch: 13 lr: 0.008000; Average loss: 0.591136, Train accuracy: 0.683438, Val accuracy: 0.632850
# saved classifier_13_0.633.ckpt
# Epoch: 14 lr: 0.008000; Average loss: 0.568555, Train accuracy: 0.710692, Val accuracy: 0.613527
# Epoch: 15 lr: 0.008000; Average loss: 0.536533, Train accuracy: 0.754717, Val accuracy: 0.628019
# Epoch: 16 lr: 0.008000; Average loss: 0.542718, Train accuracy: 0.735849, Val accuracy: 0.628019
# Epoch: 17 lr: 0.008000; Average loss: 0.499359, Train accuracy: 0.775681, Val accuracy: 0.632850
# Epoch: 18 lr: 0.008000; Average loss: 0.504811, Train accuracy: 0.775681, Val accuracy: 0.628019
# Epoch: 19 lr: 0.006400; Average loss: 0.467449, Train accuracy: 0.779874, Val accuracy: 0.628019
# Epoch: 20 lr: 0.006400; Average loss: 0.428425, Train accuracy: 0.794549, Val accuracy: 0.623188
# Epoch: 21 lr: 0.006400; Average loss: 0.406629, Train accuracy: 0.819706, Val accuracy: 0.623188
# Epoch: 22 lr: 0.006400; Average loss: 0.422609, Train accuracy: 0.796646, Val accuracy: 0.628019
# Epoch: 23 lr: 0.006400; Average loss: 0.367464, Train accuracy: 0.838574, Val accuracy: 0.632850
# Epoch: 24 lr: 0.006400; Average loss: 0.348626, Train accuracy: 0.842767, Val accuracy: 0.628019
# Epoch: 25 lr: 0.006400; Average loss: 0.314742, Train accuracy: 0.880503, Val accuracy: 0.623188
# Epoch: 26 lr: 0.006400; Average loss: 0.314623, Train accuracy: 0.867925, Val accuracy: 0.618357
# Epoch: 27 lr: 0.006400; Average loss: 0.254301, Train accuracy: 0.907757, Val accuracy: 0.603865
# Epoch: 28 lr: 0.006400; Average loss: 0.275934, Train accuracy: 0.884696, Val accuracy: 0.608696
# Epoch: 29 lr: 0.005120; Average loss: 0.238786, Train accuracy: 0.918239, Val accuracy: 0.594203
# Epoch: 30 lr: 0.005120; Average loss: 0.239966, Train accuracy: 0.901468, Val accuracy: 0.603865
# Epoch: 31 lr: 0.005120; Average loss: 0.224554, Train accuracy: 0.909853, Val accuracy: 0.599034
# Epoch: 32 lr: 0.005120; Average loss: 0.207448, Train accuracy: 0.916143, Val accuracy: 0.589372
# Epoch: 33 lr: 0.005120; Average loss: 0.201303, Train accuracy: 0.916143, Val accuracy: 0.589372
# Epoch: 34 lr: 0.005120; Average loss: 0.190615, Train accuracy: 0.928721, Val accuracy: 0.599034
# Epoch: 35 lr: 0.005120; Average loss: 0.196682, Train accuracy: 0.928721, Val accuracy: 0.613527
# Epoch: 36 lr: 0.005120; Average loss: 0.171750, Train accuracy: 0.924528, Val accuracy: 0.603865
# Epoch: 37 lr: 0.005120; Average loss: 0.160379, Train accuracy: 0.939203, Val accuracy: 0.603865
# Epoch: 38 lr: 0.005120; Average loss: 0.146608, Train accuracy: 0.937107, Val accuracy: 0.584541
# Epoch: 39 lr: 0.004096; Average loss: 0.145748, Train accuracy: 0.943396, Val accuracy: 0.589372
# Epoch: 40 lr: 0.004096; Average loss: 0.139850, Train accuracy: 0.949686, Val accuracy: 0.603865
# Epoch: 41 lr: 0.004096; Average loss: 0.123127, Train accuracy: 0.955975, Val accuracy: 0.599034
# Epoch: 42 lr: 0.004096; Average loss: 0.109173, Train accuracy: 0.962264, Val accuracy: 0.613527
# Epoch: 43 lr: 0.004096; Average loss: 0.119148, Train accuracy: 0.958071, Val accuracy: 0.594203
# Epoch: 44 lr: 0.004096; Average loss: 0.102243, Train accuracy: 0.966457, Val accuracy: 0.589372
# Epoch: 45 lr: 0.004096; Average loss: 0.081749, Train accuracy: 0.981132, Val accuracy: 0.579710
# Epoch: 46 lr: 0.004096; Average loss: 0.097649, Train accuracy: 0.972746, Val accuracy: 0.574879
# Epoch: 47 lr: 0.004096; Average loss: 0.091723, Train accuracy: 0.970650, Val accuracy: 0.570048
# Epoch: 48 lr: 0.004096; Average loss: 0.085222, Train accuracy: 0.974843, Val accuracy: 0.579710
# Epoch: 49 lr: 0.003277; Average loss: 0.098073, Train accuracy: 0.966457, Val accuracy: 0.584541
# Epoch: 50 lr: 0.003277; Average loss: 0.069560, Train accuracy: 0.981132, Val accuracy: 0.584541
# Epoch: 51 lr: 0.003277; Average loss: 0.072620, Train accuracy: 0.976939, Val accuracy: 0.579710
# Epoch: 52 lr: 0.003277; Average loss: 0.070414, Train accuracy: 0.979036, Val accuracy: 0.589372
# Epoch: 53 lr: 0.003277; Average loss: 0.073923, Train accuracy: 0.974843, Val accuracy: 0.589372
# Epoch: 54 lr: 0.003277; Average loss: 0.079567, Train accuracy: 0.974843, Val accuracy: 0.599034
# Epoch: 55 lr: 0.003277; Average loss: 0.078820, Train accuracy: 0.972746, Val accuracy: 0.594203
# Epoch: 56 lr: 0.003277; Average loss: 0.056022, Train accuracy: 0.983229, Val accuracy: 0.603865
# Epoch: 57 lr: 0.003277; Average loss: 0.053905, Train accuracy: 0.989518, Val accuracy: 0.608696
# Epoch: 58 lr: 0.003277; Average loss: 0.045981, Train accuracy: 0.991614, Val accuracy: 0.599034
# Epoch: 59 lr: 0.002621; Average loss: 0.068337, Train accuracy: 0.970650, Val accuracy: 0.589372
# Epoch: 60 lr: 0.002621; Average loss: 0.056163, Train accuracy: 0.983229, Val accuracy: 0.594203
# Epoch: 61 lr: 0.002621; Average loss: 0.042313, Train accuracy: 0.989518, Val accuracy: 0.594203
# Epoch: 62 lr: 0.002621; Average loss: 0.051713, Train accuracy: 0.989518, Val accuracy: 0.594203
# Epoch: 63 lr: 0.002621; Average loss: 0.044659, Train accuracy: 0.987421, Val accuracy: 0.599034
# Epoch: 64 lr: 0.002621; Average loss: 0.050848, Train accuracy: 0.989518, Val accuracy: 0.613527
# Epoch: 65 lr: 0.002621; Average loss: 0.044013, Train accuracy: 0.993711, Val accuracy: 0.603865
# Epoch: 66 lr: 0.002621; Average loss: 0.030450, Train accuracy: 0.995807, Val accuracy: 0.603865
# Epoch: 67 lr: 0.002621; Average loss: 0.044223, Train accuracy: 0.985325, Val accuracy: 0.599034
# Epoch: 68 lr: 0.002621; Average loss: 0.039317, Train accuracy: 0.989518, Val accuracy: 0.579710
# Epoch: 69 lr: 0.002097; Average loss: 0.036135, Train accuracy: 0.991614, Val accuracy: 0.589372
# Epoch: 70 lr: 0.002097; Average loss: 0.043330, Train accuracy: 0.989518, Val accuracy: 0.589372
# Epoch: 71 lr: 0.002097; Average loss: 0.046875, Train accuracy: 0.985325, Val accuracy: 0.584541
# Epoch: 72 lr: 0.002097; Average loss: 0.032641, Train accuracy: 0.993711, Val accuracy: 0.599034
# Epoch: 73 lr: 0.002097; Average loss: 0.042564, Train accuracy: 0.987421, Val accuracy: 0.608696
# Epoch: 74 lr: 0.002097; Average loss: 0.041996, Train accuracy: 0.983229, Val accuracy: 0.613527
# Epoch: 75 lr: 0.002097; Average loss: 0.043339, Train accuracy: 0.985325, Val accuracy: 0.608696
# Epoch: 76 lr: 0.002097; Average loss: 0.024307, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 77 lr: 0.002097; Average loss: 0.031464, Train accuracy: 0.993711, Val accuracy: 0.584541
# Epoch: 78 lr: 0.002097; Average loss: 0.040982, Train accuracy: 0.987421, Val accuracy: 0.584541
# Epoch: 79 lr: 0.001678; Average loss: 0.033673, Train accuracy: 0.983229, Val accuracy: 0.579710
# Epoch: 80 lr: 0.001678; Average loss: 0.035082, Train accuracy: 0.993711, Val accuracy: 0.589372
# Epoch: 81 lr: 0.001678; Average loss: 0.031345, Train accuracy: 0.995807, Val accuracy: 0.589372
# Epoch: 82 lr: 0.001678; Average loss: 0.024926, Train accuracy: 0.993711, Val accuracy: 0.584541
# Epoch: 83 lr: 0.001678; Average loss: 0.026143, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 84 lr: 0.001678; Average loss: 0.039302, Train accuracy: 0.987421, Val accuracy: 0.599034
# Epoch: 85 lr: 0.001678; Average loss: 0.033457, Train accuracy: 0.987421, Val accuracy: 0.584541
# Epoch: 86 lr: 0.001678; Average loss: 0.027180, Train accuracy: 0.991614, Val accuracy: 0.574879
# Epoch: 87 lr: 0.001678; Average loss: 0.031894, Train accuracy: 0.989518, Val accuracy: 0.574879
# Epoch: 88 lr: 0.001678; Average loss: 0.021453, Train accuracy: 0.995807, Val accuracy: 0.584541
# Epoch: 89 lr: 0.001342; Average loss: 0.025106, Train accuracy: 0.995807, Val accuracy: 0.584541
# Epoch: 90 lr: 0.001342; Average loss: 0.034705, Train accuracy: 0.991614, Val accuracy: 0.579710
# Epoch: 91 lr: 0.001342; Average loss: 0.032656, Train accuracy: 0.991614, Val accuracy: 0.584541
# Epoch: 92 lr: 0.001342; Average loss: 0.031015, Train accuracy: 0.987421, Val accuracy: 0.603865
# Epoch: 93 lr: 0.001342; Average loss: 0.024481, Train accuracy: 0.995807, Val accuracy: 0.618357
# Epoch: 94 lr: 0.001342; Average loss: 0.036975, Train accuracy: 0.989518, Val accuracy: 0.608696
# Epoch: 95 lr: 0.001342; Average loss: 0.021298, Train accuracy: 0.993711, Val accuracy: 0.623188
# Epoch: 96 lr: 0.001342; Average loss: 0.040034, Train accuracy: 0.983229, Val accuracy: 0.608696
# Epoch: 97 lr: 0.001342; Average loss: 0.019635, Train accuracy: 0.997904, Val accuracy: 0.603865
# Epoch: 98 lr: 0.001342; Average loss: 0.026771, Train accuracy: 0.993711, Val accuracy: 0.579710
# Epoch: 99 lr: 0.001074; Average loss: 0.035553, Train accuracy: 0.983229, Val accuracy: 0.589372
# Epoch: 100 lr: 0.001074; Average loss: 0.025109, Train accuracy: 0.989518, Val accuracy: 0.599034
# Epoch: 101 lr: 0.001074; Average loss: 0.026821, Train accuracy: 0.989518, Val accuracy: 0.584541
# Epoch: 102 lr: 0.001074; Average loss: 0.029258, Train accuracy: 0.991614, Val accuracy: 0.589372
# Epoch: 103 lr: 0.001074; Average loss: 0.013654, Train accuracy: 1.000000, Val accuracy: 0.603865
# Epoch: 104 lr: 0.001074; Average loss: 0.014917, Train accuracy: 0.997904, Val accuracy: 0.594203
# Epoch: 105 lr: 0.001074; Average loss: 0.018133, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 106 lr: 0.001074; Average loss: 0.021144, Train accuracy: 0.993711, Val accuracy: 0.599034
# Epoch: 107 lr: 0.001074; Average loss: 0.017263, Train accuracy: 0.997904, Val accuracy: 0.603865
# Epoch: 108 lr: 0.001074; Average loss: 0.024610, Train accuracy: 0.991614, Val accuracy: 0.603865
# Epoch: 109 lr: 0.000859; Average loss: 0.019929, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 110 lr: 0.000859; Average loss: 0.022757, Train accuracy: 0.995807, Val accuracy: 0.603865
# Epoch: 111 lr: 0.000859; Average loss: 0.018542, Train accuracy: 0.997904, Val accuracy: 0.603865
# Epoch: 112 lr: 0.000859; Average loss: 0.020202, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 113 lr: 0.000859; Average loss: 0.017071, Train accuracy: 0.997904, Val accuracy: 0.594203
# Epoch: 114 lr: 0.000859; Average loss: 0.015880, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 115 lr: 0.000859; Average loss: 0.017396, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 116 lr: 0.000859; Average loss: 0.019319, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 117 lr: 0.000859; Average loss: 0.015061, Train accuracy: 0.995807, Val accuracy: 0.603865
# Epoch: 118 lr: 0.000859; Average loss: 0.013724, Train accuracy: 1.000000, Val accuracy: 0.599034
# Epoch: 119 lr: 0.000687; Average loss: 0.015312, Train accuracy: 0.997904, Val accuracy: 0.589372
# Epoch: 120 lr: 0.000687; Average loss: 0.015321, Train accuracy: 0.997904, Val accuracy: 0.589372
# Epoch: 121 lr: 0.000687; Average loss: 0.022615, Train accuracy: 0.993711, Val accuracy: 0.599034
# Epoch: 122 lr: 0.000687; Average loss: 0.016957, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 123 lr: 0.000687; Average loss: 0.018105, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 124 lr: 0.000687; Average loss: 0.013441, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 125 lr: 0.000687; Average loss: 0.012967, Train accuracy: 0.997904, Val accuracy: 0.603865
# Epoch: 126 lr: 0.000687; Average loss: 0.012842, Train accuracy: 0.997904, Val accuracy: 0.594203
# Epoch: 127 lr: 0.000687; Average loss: 0.016228, Train accuracy: 0.995807, Val accuracy: 0.603865
# Epoch: 128 lr: 0.000687; Average loss: 0.018568, Train accuracy: 0.997904, Val accuracy: 0.603865
# Epoch: 129 lr: 0.000550; Average loss: 0.015986, Train accuracy: 1.000000, Val accuracy: 0.599034
# Epoch: 130 lr: 0.000550; Average loss: 0.015675, Train accuracy: 0.997904, Val accuracy: 0.603865
# Epoch: 131 lr: 0.000550; Average loss: 0.016608, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 132 lr: 0.000550; Average loss: 0.013961, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 133 lr: 0.000550; Average loss: 0.026145, Train accuracy: 0.989518, Val accuracy: 0.603865
# Epoch: 134 lr: 0.000550; Average loss: 0.008690, Train accuracy: 1.000000, Val accuracy: 0.603865
# Epoch: 135 lr: 0.000550; Average loss: 0.010301, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 136 lr: 0.000550; Average loss: 0.016015, Train accuracy: 0.993711, Val accuracy: 0.599034
# Epoch: 137 lr: 0.000550; Average loss: 0.015355, Train accuracy: 0.995807, Val accuracy: 0.594203
# Epoch: 138 lr: 0.000550; Average loss: 0.024681, Train accuracy: 0.991614, Val accuracy: 0.589372
# Epoch: 139 lr: 0.000440; Average loss: 0.017514, Train accuracy: 0.995807, Val accuracy: 0.584541
# Epoch: 140 lr: 0.000440; Average loss: 0.016445, Train accuracy: 0.997904, Val accuracy: 0.579710
# Epoch: 141 lr: 0.000440; Average loss: 0.024383, Train accuracy: 0.993711, Val accuracy: 0.579710
# Epoch: 142 lr: 0.000440; Average loss: 0.013292, Train accuracy: 0.997904, Val accuracy: 0.579710
# Epoch: 143 lr: 0.000440; Average loss: 0.013270, Train accuracy: 0.997904, Val accuracy: 0.579710
# Epoch: 144 lr: 0.000440; Average loss: 0.012883, Train accuracy: 0.997904, Val accuracy: 0.584541
# Epoch: 145 lr: 0.000440; Average loss: 0.014585, Train accuracy: 0.997904, Val accuracy: 0.584541
# Epoch: 146 lr: 0.000440; Average loss: 0.011334, Train accuracy: 0.997904, Val accuracy: 0.579710
# Epoch: 147 lr: 0.000440; Average loss: 0.023788, Train accuracy: 0.995807, Val accuracy: 0.589372
# Epoch: 148 lr: 0.000440; Average loss: 0.011290, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 149 lr: 0.000352; Average loss: 0.008613, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 150 lr: 0.000352; Average loss: 0.015467, Train accuracy: 0.995807, Val accuracy: 0.594203
# Epoch: 151 lr: 0.000352; Average loss: 0.019735, Train accuracy: 0.997904, Val accuracy: 0.589372
# Epoch: 152 lr: 0.000352; Average loss: 0.011956, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 153 lr: 0.000352; Average loss: 0.010987, Train accuracy: 1.000000, Val accuracy: 0.589372
# Epoch: 154 lr: 0.000352; Average loss: 0.017873, Train accuracy: 0.995807, Val accuracy: 0.589372
# Epoch: 155 lr: 0.000352; Average loss: 0.012202, Train accuracy: 0.997904, Val accuracy: 0.589372
# Epoch: 156 lr: 0.000352; Average loss: 0.016683, Train accuracy: 0.997904, Val accuracy: 0.584541
# Epoch: 157 lr: 0.000352; Average loss: 0.024236, Train accuracy: 0.991614, Val accuracy: 0.584541
# Epoch: 158 lr: 0.000352; Average loss: 0.014215, Train accuracy: 0.997904, Val accuracy: 0.589372
# Epoch: 159 lr: 0.000281; Average loss: 0.016948, Train accuracy: 0.997904, Val accuracy: 0.584541
# Epoch: 160 lr: 0.000281; Average loss: 0.014246, Train accuracy: 0.995807, Val accuracy: 0.589372
# Epoch: 161 lr: 0.000281; Average loss: 0.015975, Train accuracy: 0.995807, Val accuracy: 0.584541
# Epoch: 162 lr: 0.000281; Average loss: 0.015826, Train accuracy: 0.993711, Val accuracy: 0.584541
# Epoch: 163 lr: 0.000281; Average loss: 0.013825, Train accuracy: 0.995807, Val accuracy: 0.589372
# Epoch: 164 lr: 0.000281; Average loss: 0.011362, Train accuracy: 0.997904, Val accuracy: 0.584541
# Epoch: 165 lr: 0.000281; Average loss: 0.010658, Train accuracy: 0.997904, Val accuracy: 0.589372
# Epoch: 166 lr: 0.000281; Average loss: 0.014806, Train accuracy: 0.995807, Val accuracy: 0.589372
# Epoch: 167 lr: 0.000281; Average loss: 0.014235, Train accuracy: 0.997904, Val accuracy: 0.589372
# Epoch: 168 lr: 0.000281; Average loss: 0.012020, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 169 lr: 0.000225; Average loss: 0.013907, Train accuracy: 0.997904, Val accuracy: 0.594203
# Epoch: 170 lr: 0.000225; Average loss: 0.013799, Train accuracy: 0.997904, Val accuracy: 0.594203
# Epoch: 171 lr: 0.000225; Average loss: 0.016845, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 172 lr: 0.000225; Average loss: 0.012103, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 173 lr: 0.000225; Average loss: 0.015189, Train accuracy: 0.993711, Val accuracy: 0.599034
# Epoch: 174 lr: 0.000225; Average loss: 0.018309, Train accuracy: 0.995807, Val accuracy: 0.594203
# Epoch: 175 lr: 0.000225; Average loss: 0.013535, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 176 lr: 0.000225; Average loss: 0.013172, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 177 lr: 0.000225; Average loss: 0.012189, Train accuracy: 1.000000, Val accuracy: 0.599034
# Epoch: 178 lr: 0.000225; Average loss: 0.012266, Train accuracy: 1.000000, Val accuracy: 0.599034
# Epoch: 179 lr: 0.000180; Average loss: 0.021568, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 180 lr: 0.000180; Average loss: 0.011940, Train accuracy: 0.995807, Val accuracy: 0.594203
# Epoch: 181 lr: 0.000180; Average loss: 0.010531, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 182 lr: 0.000180; Average loss: 0.012608, Train accuracy: 0.997904, Val accuracy: 0.594203
# Epoch: 183 lr: 0.000180; Average loss: 0.016486, Train accuracy: 0.997904, Val accuracy: 0.594203
# Epoch: 184 lr: 0.000180; Average loss: 0.015832, Train accuracy: 0.993711, Val accuracy: 0.594203
# Epoch: 185 lr: 0.000180; Average loss: 0.012028, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 186 lr: 0.000180; Average loss: 0.012147, Train accuracy: 1.000000, Val accuracy: 0.603865
# Epoch: 187 lr: 0.000180; Average loss: 0.015780, Train accuracy: 0.995807, Val accuracy: 0.603865
# Epoch: 188 lr: 0.000180; Average loss: 0.009766, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 189 lr: 0.000144; Average loss: 0.008520, Train accuracy: 1.000000, Val accuracy: 0.603865
# Epoch: 190 lr: 0.000144; Average loss: 0.018296, Train accuracy: 0.993711, Val accuracy: 0.603865
# Epoch: 191 lr: 0.000144; Average loss: 0.016861, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 192 lr: 0.000144; Average loss: 0.015593, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 193 lr: 0.000144; Average loss: 0.011370, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 194 lr: 0.000144; Average loss: 0.011277, Train accuracy: 0.997904, Val accuracy: 0.599034
# Epoch: 195 lr: 0.000144; Average loss: 0.014355, Train accuracy: 0.995807, Val accuracy: 0.599034
# Epoch: 196 lr: 0.000144; Average loss: 0.013140, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 197 lr: 0.000144; Average loss: 0.009437, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 198 lr: 0.000144; Average loss: 0.008895, Train accuracy: 1.000000, Val accuracy: 0.594203
# Epoch: 199 lr: 0.000115; Average loss: 0.013483, Train accuracy: 0.995807, Val accuracy: 0.594203
# end!

# %%
fig = plt.figure(figsize=(10, 8))    
plt.xlabel("#iteration")
plt.ylabel("loss")
plt.plot(loss_history, label='loss')
plt.plot(train_history, label='train accuracy')
plt.plot(val_history, label='val accuracy')
fig.legend()
plt.show()

# %%
print("best model:", best_model_name)

best_model = torch.load(open(best_model_name, 'rb'))
print(best_model)
# Out:
# best model: classifier_13_0.633.ckpt
# Sequential(
#   (0): Linear(in_features=1536, out_features=256, bias=True)
#   (1): Dropout(p=0.66, inplace=False)
#   (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): ReLU(inplace=True)
#   (4): Linear(in_features=256, out_features=256, bias=True)
#   (5): Dropout(p=0.66, inplace=False)
#   (6): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): ReLU(inplace=True)
#   (8): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
best_model.eval()
for i_step, (x, y) in enumerate(DataLoader(features_val_dataset, batch_size=5000)):
    prediction = best_model(x)

acc_score = accuracy_score(np.array([x.item() for x in labels_val]), torch.max(prediction, 1)[1])
auc_score = roc_auc_score(np.array([x.item() for x in labels_val]), prediction[:,1].detach().numpy())
prettyTable.add_row(['Neural Network', acc_score, auc_score])

fpr, tpr, thresh = roc_curve(labels_val, prediction[:,1].detach().numpy(), pos_label=1)

random_probs = [0 for i in range(len(labels_val))]
p_fpr, p_tpr, _ = roc_curve(labels_val, random_probs, pos_label=1)
auc_score = roc_auc_score(labels_val, prediction[:,1].detach().numpy())

print('Accuracy: ', acc_score, '\n', 'ROC AUC: ', auc_score, sep='')

plt.plot(fpr, tpr, linestyle='--',color='orange')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.title('ROC Curve', fontsize=20)
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive rate',fontsize=18)

plt.show();
# Out:
# Accuracy: 0.6328502415458938
# ROC AUC: 0.6266811708860759

# %%
print(prettyTable)
# Out:
# +----------------+--------------------+--------------------+
# |   Model name   |      Accuracy      |      ROC AUC       |
# +----------------+--------------------+--------------------+
# | Neural Network | 0.6328502415458938 | 0.6266811708860759 |
# +----------------+--------------------+--------------------+
